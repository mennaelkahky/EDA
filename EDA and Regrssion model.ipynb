# %% [markdown]
# # Import Libraries

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns 
import category_encoders as ce

# %% [markdown]
# # Load Data

# %%
df= pd.read_csv("C:/Users/Ram/Downloads/train.csv")

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %%
df.shape
# Out:
# (1460, 81)

# %% [markdown]
# # Data Exploration

# %% [markdown]
# # Count missing values in each column

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             1460 non-null   int64
#  1   MSSubClass     1460 non-null   int64
#  2   MSZoning       1460 non-null   object
#  3   LotFrontage    1201 non-null   float64
#  4   LotArea        1460 non-null   int64
#  5   Street         1460 non-null   object
#  6   Alley          91 non-null     object
#  7   LotShape       1460 non-null   object
#  8   LandContour    1460 non-null   object
#  9   Utilities      1460 non-null   object
#  10  LotConfig      1460 non-null   object
#  11  LandSlope      1460 non-null   object
#  12  Neighborhood   1460 non-null   object
#  13  Condition1     1460 non-null   object
#  14  Condition2     1460 non-null   object
#  15  BldgType       1460 non-null   object
#  16  HouseStyle     1460 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
df["PoolQC"].isna().sum()
# Out:
# 1453

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# Check fields with large missing data from the description:
#
#
# *   PoolQC means Pool Quality and NA means No Pool (it is not a missing value and it will impact the peroformance). You will notice that values are (Ex	Excellent, Gd	Good, TA	Average/Typical, Fa	Fair, NA	No Pool). The order here make sense
# *   Find and replace is the best approach in this case

# %%
# create a dictionary use table names and values

# %%
df["PoolQC"].value_counts()
# Out:
# PoolQC
# Gd    3
# Ex    2
# Fa    2
# Name: count, dtype: int64

# %%
df["PoolQC"].fillna("No Pool",inplace=True)
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
pool_mapping = {'Ex': 4, 'Gd': 3, 'TA': 2, 'Fa': 1, 'No Pool': 0}
df['PoolQC_encoded'] = df['PoolQC'].map(pool_mapping)
df.drop("PoolQC",axis=1, inplace=True)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour Utilities  ... PoolArea  Fence MiscFeature MiscVal MoSold  \
# 1455         Lvl    AllPub  ...        0    NaN         NaN       0      8
# 1456         Lvl    AllPub  ...        0  MnPrv         NaN       0      2
# 1457         Lvl    AllPub  ...        0  GdPrv        Shed    2500      5
# 1458         Lvl    AllPub  ...        0    NaN         NaN       0      4
# 1459         Lvl    AllPub  ...        0    NaN         NaN       0      6
#
# ...

# %%
df["MiscFeature"].value_counts()
# Out:
# MiscFeature
# Shed    49
# Gar2     2
# Othr     2
# TenC     1
# Name: count, dtype: int64

# %%
df["MiscFeature"].fillna("Shed",inplace=True)
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
import sklearn

# %%
encoder = ce.OneHotEncoder(cols=['MiscFeature'])

# %%
encoder
# Out:
# OneHotEncoder(cols=['MiscFeature'])

# %%
df=encoder.fit_transform(df)
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# *   MiscFeature includes: Elev	Elevator, Gar2	2nd Garage (if not
# described in garage section), Othr	Other, Shed	Shed (over 100 SF), TenC	Tennis Court, NA	None
# *    Replacing NA with the most frequent term does not make sense here
# *    We can use None as a separate category
# *    One hot encoding will be a good choice here

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %% [markdown]
# Alley: Type of alley access to property. The field values are defined as:
# *   Grvl	Gravel
# *   Pave	Paved
# *   NA 	No alley access
#
# Similar to MiscFeature, we can use None as a separate category and One hot encoding will be a good choice here

# %%
df["Alley"].value_counts()
# Out:
# Alley
# Grvl    50
# Pave    41
# Name: count, dtype: int64

# %%
df["Alley"].isna().sum()
# Out:
# 1369

# %%
df["Alley"].fillna("No alley",inplace=True)

# %%
df["Alley"].isna().sum()
# Out:
# 0

# %%
o_encoder = ce.OneHotEncoder(cols=['Alley'])

# %%
df=o_encoder.fit_transform(df)
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley_1  \
# 0        1          60       RL         65.0     8450   Pave        1
# 1        2          20       RL         80.0     9600   Pave        1
# 2        3          60       RL         68.0    11250   Pave        1
# 3        4          70       RL         60.0     9550   Pave        1
# 4        5          60       RL         84.0    14260   Pave        1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave        1
# 1456  1457          20       RL         85.0    13175   Pave        1
# 1457  1458          70       RL         66.0     9042   Pave        1
# 1458  1459          20       RL         68.0     9717   Pave        1
# 1459  1460          20       RL         75.0     9937   Pave        1
#
#       Alley_2  Alley_3 LotShape  ... MiscFeature_2 MiscFeature_3  \
# ...

# %% [markdown]
# Fence: Fence quality.  The field values are defined as
# *   GdPrv	Good Privacy
# *   MnPrv	Minimum Privacy
# *   GdWo	Good Wood
# *   MnWw	Minimum Wood/Wire
# *   NA	No Fence
#
# We will use the above technique

# %%
df["Fence"].unique()
# Out:
# array([nan, 'MnPrv', 'GdWo', 'GdPrv', 'MnWw'], dtype=object)

# %%
df["Fence"].fillna("No Fence",inplace=True)

# %%
fence_mapping = {'GdPrv': 4, 'MnPrv': 3, 'GdWo': 2, 'MnWw': 1, 'No Fence': 0}
df['Fence_encoded'] = df['Fence'].map(fence_mapping)
df.drop("Fence",axis=1, inplace=True)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley_1  \
# 0        1          60       RL         65.0     8450   Pave        1
# 1        2          20       RL         80.0     9600   Pave        1
# 2        3          60       RL         68.0    11250   Pave        1
# 3        4          70       RL         60.0     9550   Pave        1
# 4        5          60       RL         84.0    14260   Pave        1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave        1
# 1456  1457          20       RL         85.0    13175   Pave        1
# 1457  1458          70       RL         66.0     9042   Pave        1
# 1458  1459          20       RL         68.0     9717   Pave        1
# 1459  1460          20       RL         75.0     9937   Pave        1
#
#       Alley_2  Alley_3 LotShape  ... MiscFeature_3 MiscFeature_4 MiscVal  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 86 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Id              1460 non-null   int64
#  1   MSSubClass      1460 non-null   int64
#  2   MSZoning        1460 non-null   object
#  3   LotFrontage     1201 non-null   float64
#  4   LotArea         1460 non-null   int64
#  5   Street          1460 non-null   object
#  6   Alley_1         1460 non-null   int64
#  7   Alley_2         1460 non-null   int64
#  8   Alley_3         1460 non-null   int64
#  9   LotShape        1460 non-null   object
#  10  LandContour     1460 non-null   object
#  11  Utilities       1460 non-null   object
#  12  LotConfig       1460 non-null   object
#  13  LandSlope       1460 non-null   object
#  14  Neighborhood    1460 non-null   object
#  15  Condition1      1460 non-null   object
#  16  Condition2      1460 non-null   object
# ...

# %% [markdown]
# FireplaceQu: Fireplace quality
#
#        Ex	Excellent - Exceptional Masonry Fireplace
#        Gd	Good - Masonry Fireplace in main level
#        TA	Average - Prefabricated Fireplace in main living area or Masonry Fireplace in basement
#        Fa	Fair - Prefabricated Fireplace in basement
#        Po	Poor - Ben Franklin Stove
#        NA	No Fireplace
#
#
# We will use find and replace

# %%
df["FireplaceQu"].value_counts()
# Out:
# FireplaceQu
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: count, dtype: int64

# %%
df["FireplaceQu"].fillna("No Fireplace",inplace=True)

# %%
fireplace_mapping = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, "Po":1,'No Fireplace': 0}
df['Fireplacequ_encoded'] = df['FireplaceQu'].map(fireplace_mapping)
df.drop("FireplaceQu",axis=1, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 86 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1460 non-null   int64
#  1   MSSubClass           1460 non-null   int64
#  2   MSZoning             1460 non-null   object
#  3   LotFrontage          1201 non-null   float64
#  4   LotArea              1460 non-null   int64
#  5   Street               1460 non-null   object
#  6   Alley_1              1460 non-null   int64
#  7   Alley_2              1460 non-null   int64
#  8   Alley_3              1460 non-null   int64
#  9   LotShape             1460 non-null   object
#  10  LandContour          1460 non-null   object
#  11  Utilities            1460 non-null   object
#  12  LotConfig            1460 non-null   object
#  13  LandSlope            1460 non-null   object
#  14  Neighborhood         1460 non-null   object
# ...

# %% [markdown]
# The last item is the lot frontage (واجهة الشارع).Linear feet of street connected to property.
#
#
# We may use the median in this case

# %%
df["LotFrontage"].unique()
# Out:
# array([ 65.,  80.,  68.,  60.,  84.,  85.,  75.,  nan,  51.,  50.,  70.,
#         91.,  72.,  66., 101.,  57.,  44., 110.,  98.,  47., 108., 112.,
#         74., 115.,  61.,  48.,  33.,  52., 100.,  24.,  89.,  63.,  76.,
#         81.,  95.,  69.,  21.,  32.,  78., 121., 122.,  40., 105.,  73.,
#         77.,  64.,  94.,  34.,  90.,  55.,  88.,  82.,  71., 120., 107.,
#         92., 134.,  62.,  86., 141.,  97.,  54.,  41.,  79., 174.,  99.,
#         67.,  83.,  43., 103.,  93.,  30., 129., 140.,  35.,  37., 118.,
#         87., 116., 150., 111.,  49.,  96.,  59.,  36.,  56., 102.,  58.,
#         38., 109., 130.,  53., 137.,  45., 106., 104.,  42.,  39., 144.,
#        114., 128., 149., 313., 168., 182., 138., 160., 152., 124., 153.,
#         46.])

# %%
df['LotFrontage'].fillna(df['LotFrontage'].median(), inplace=True)

# %%
df["LotFrontage"].isna().sum()
# Out:
# 0

# %%
df["GarageType"].fillna("No grage",inplace=True)

# %%
df["GarageType"].unique()
# Out:
# array(['Attchd', 'Detchd', 'BuiltIn', 'CarPort', 'No grage', 'Basment',
#        '2Types'], dtype=object)

# %%
encoder2 = ce.OneHotEncoder(cols=['GarageType'])
df=encoder2.fit_transform(df)
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley_1  \
# 0        1          60       RL         65.0     8450   Pave        1
# 1        2          20       RL         80.0     9600   Pave        1
# 2        3          60       RL         68.0    11250   Pave        1
# 3        4          70       RL         60.0     9550   Pave        1
# 4        5          60       RL         84.0    14260   Pave        1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave        1
# 1456  1457          20       RL         85.0    13175   Pave        1
# 1457  1458          70       RL         66.0     9042   Pave        1
# 1458  1459          20       RL         68.0     9717   Pave        1
# 1459  1460          20       RL         75.0     9937   Pave        1
#
#       Alley_2  Alley_3 LotShape  ... MiscFeature_4 MiscVal MoSold YrSold  \
# ...

# %%
df["MasVnrArea"].fillna(df['MasVnrArea'].median(), inplace=True)

# %%
df["Electrical"].value_counts()
# Out:
# Electrical
# SBrkr    1334
# FuseA      94
# FuseF      27
# FuseP       3
# Mix         1
# Name: count, dtype: int64

# %%
df["Electrical"].fillna("SBrkr",inplace=True)

# %%
E_encoder = ce.OneHotEncoder(cols=['Electrical'])
df=E_encoder.fit_transform(df)

# %%
df["MasVnrType"].fillna("No Masvn",inplace=True)

# %%
df["MasVnrType"].unique()
# Out:
# array(['BrkFace', 'No Masvn', 'Stone', 'BrkCmn'], dtype=object)

# %%
M_encoder = ce.OneHotEncoder(cols=['MasVnrType'])
df=M_encoder.fit_transform(df)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley_1  \
# 0        1          60       RL         65.0     8450   Pave        1
# 1        2          20       RL         80.0     9600   Pave        1
# 2        3          60       RL         68.0    11250   Pave        1
# 3        4          70       RL         60.0     9550   Pave        1
# 4        5          60       RL         84.0    14260   Pave        1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave        1
# 1456  1457          20       RL         85.0    13175   Pave        1
# 1457  1458          70       RL         66.0     9042   Pave        1
# 1458  1459          20       RL         68.0     9717   Pave        1
# 1459  1460          20       RL         75.0     9937   Pave        1
#
#       Alley_2  Alley_3 LotShape  ... MiscFeature_4 MiscVal MoSold YrSold  \
# ...

# %%
df["GarageCond"].fillna("No",inplace=True)

# %%
G_mapping = {'Ex': 5, 'Gd': 4, 'TA': 3, 'Fa': 2, "Po":1,'No': 0}
df['G_encoded'] = df['GarageCond'].map(G_mapping)
df.drop("GarageCond",axis=1, inplace=True)

# %%
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street  Alley_1  \
# 0        1          60       RL         65.0     8450   Pave        1
# 1        2          20       RL         80.0     9600   Pave        1
# 2        3          60       RL         68.0    11250   Pave        1
# 3        4          70       RL         60.0     9550   Pave        1
# 4        5          60       RL         84.0    14260   Pave        1
# ...    ...         ...      ...          ...      ...    ...      ...
# 1455  1456          60       RL         62.0     7917   Pave        1
# 1456  1457          20       RL         85.0    13175   Pave        1
# 1457  1458          70       RL         66.0     9042   Pave        1
# 1458  1459          20       RL         68.0     9717   Pave        1
# 1459  1460          20       RL         75.0     9937   Pave        1
#
#       Alley_2  Alley_3 LotShape  ... MiscVal MoSold YrSold SaleType  \
# ...

# %%
df["BsmtQual"].isna().sum()
# Out:
# 37

# %%
df["BsmtQual"].value_counts()
# Out:
# BsmtQual
# TA    649
# Gd    618
# Ex    121
# Fa     35
# Name: count, dtype: int64

# %%
df["BsmtQual"].fillna("TA",inplace=True)

# %%
df["BsmtQual"].isna().sum()
# Out:
# 0

# %%
BsmtQual_mapping = {'Ex': 0, 'Gd': 1, 'TA': 2, 'Fa': 3}
df['BsmtQual'] = df['BsmtQual'].map(BsmtQual_mapping)
df.drop("BsmtQual",axis=1, inplace=True)

# %%
df["BsmtCond"].value_counts()
# Out:
# BsmtCond
# TA    1311
# Gd      65
# Fa      45
# Po       2
# Name: count, dtype: int64

# %%
df["BsmtCond"].fillna("TA",inplace=True)

# %%
BsmtCond_mapping = {'Po': 0, 'Gd': 1, 'TA': 2, 'Fa': 3}
df['BsmtCond'] = df['BsmtCond'].map(BsmtCond_mapping)
df.drop("BsmtCond",axis=1, inplace=True)

# %%
df["BsmtFinType1"].value_counts()
# Out:
# BsmtFinType1
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: count, dtype: int64

# %%
df["BsmtFinType1"].fillna("Unf",inplace=True)

# %%
b_encoder = ce.OneHotEncoder(cols=['BsmtFinType1'])
df=b_encoder.fit_transform(df)

# %%
df["BsmtFinType2"].value_counts()
# Out:
# BsmtFinType2
# Unf    1256
# Rec      54
# LwQ      46
# BLQ      33
# ALQ      19
# GLQ      14
# Name: count, dtype: int64

# %%
df["BsmtFinType2"].fillna("Unf",inplace=True)

# %%
b_encoder = ce.OneHotEncoder(cols=['BsmtFinType2'])
df=b_encoder.fit_transform(df)

# %%
df["BsmtExposure"].value_counts()
# Out:
# BsmtExposure
# No    953
# Av    221
# Gd    134
# Mn    114
# Name: count, dtype: int64

# %%
df["BsmtExposure"].fillna("No",inplace=True)

# %%
Bsmt_mapping = {'No': 0, 'Gd': 1, 'Mn': 2, 'Av': 3}
df['BsmtExposure'] = df['BsmtExposure'].map(Bsmt_mapping)
df.drop("BsmtExposure",axis=1, inplace=True)

# %%
df["GarageFinish"].value_counts()
# Out:
# GarageFinish
# Unf    605
# RFn    422
# Fin    352
# Name: count, dtype: int64

# %%
df["GarageFinish"].fillna("Unf",inplace=True)

# %%
g_encoder = ce.OneHotEncoder(cols=['GarageFinish'])
df=g_encoder.fit_transform(df)

# %%
df["GarageQual"].value_counts()
# Out:
# GarageQual
# TA    1311
# Fa      48
# Gd      14
# Ex       3
# Po       3
# Name: count, dtype: int64

# %%
df["GarageQual"].fillna("TA",inplace=True)

# %%
ga_mapping = {'Po': 0, 'Gd': 1, 'TA': 2, 'Fa': 3,"Ex":4}
df['GarageQual'] = df['GarageQual'].map(ga_mapping)
df.drop("GarageQual",axis=1, inplace=True)

# %%
df["GarageYrBlt"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 1460 entries, 0 to 1459
# Series name: GarageYrBlt
# Non-Null Count  Dtype
# --------------  -----
# 1379 non-null   float64
# dtypes: float64(1)
# memory usage: 11.5 KB

# %%
df["GarageYrBlt"].value_counts()
# Out:
# GarageYrBlt
# 2005.0    65
# 2006.0    59
# 2004.0    53
# 2003.0    50
# 2007.0    49
#           ..
# 1927.0     1
# 1900.0     1
# 1906.0     1
# 1908.0     1
# 1933.0     1
# Name: count, Length: 97, dtype: int64

# %%
df["GarageYrBlt"].fillna("2005.0",inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 107 entries, Id to G_encoded
# dtypes: float64(2), int64(77), object(28)
# memory usage: 1.2+ MB

# %%
numerical_data= [feature for feature in df.columns if df[feature].dtype !="object"]
numerical_data
# Out:
# ['Id',
#  'MSSubClass',
#  'LotFrontage',
#  'LotArea',
#  'Alley_1',
#  'Alley_2',
#  'Alley_3',
#  'OverallQual',
#  'OverallCond',
#  'YearBuilt',
#  'YearRemodAdd',
#  'MasVnrType_1',
#  'MasVnrType_2',
#  'MasVnrType_3',
#  'MasVnrType_4',
#  'MasVnrArea',
#  'BsmtFinType1_1',
#  'BsmtFinType1_2',
#  'BsmtFinType1_3',
#  'BsmtFinType1_4',
#  'BsmtFinType1_5',
#  'BsmtFinType1_6',
#  'BsmtFinSF1',
#  'BsmtFinType2_1',
#  'BsmtFinType2_2',
#  'BsmtFinType2_3',
#  'BsmtFinType2_4',
#  'BsmtFinType2_5',
#  'BsmtFinType2_6',
#  'BsmtFinSF2',
#  'BsmtUnfSF',
#  'TotalBsmtSF',
#  'Electrical_1',
#  'Electrical_2',
#  'Electrical_3',
#  'Electrical_4',
#  'Electrical_5',
#  '1stFlrSF',
#  '2ndFlrSF',
#  'LowQualFinSF',
#  'GrLivArea',
#  'BsmtFullBath',
#  'BsmtHalfBath',
#  'FullBath',
#  'HalfBath',
#  'BedroomAbvGr',
#  'KitchenAbvGr',
#  'TotRmsAbvGrd',
#  'Fireplaces',
#  'GarageType_1',
#  'GarageType_2',
#  'GarageType_3',
#  'GarageType_4',
#  'GarageType_5',
#  'GarageType_6',
# ...

# %%
df[numerical_data].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 79 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Id                   1460 non-null   int64
#  1   MSSubClass           1460 non-null   int64
#  2   LotFrontage          1460 non-null   float64
#  3   LotArea              1460 non-null   int64
#  4   Alley_1              1460 non-null   int64
#  5   Alley_2              1460 non-null   int64
#  6   Alley_3              1460 non-null   int64
#  7   OverallQual          1460 non-null   int64
#  8   OverallCond          1460 non-null   int64
#  9   YearBuilt            1460 non-null   int64
#  10  YearRemodAdd         1460 non-null   int64
#  11  MasVnrType_1         1460 non-null   int64
#  12  MasVnrType_2         1460 non-null   int64
#  13  MasVnrType_3         1460 non-null   int64
#  14  MasVnrType_4         1460 non-null   int64
# ...

# %%
categorical_data= [feature for feature in df.columns if df[feature].dtype =="object"]
categorical_data
# Out:
# ['MSZoning',
#  'Street',
#  'LotShape',
#  'LandContour',
#  'Utilities',
#  'LotConfig',
#  'LandSlope',
#  'Neighborhood',
#  'Condition1',
#  'Condition2',
#  'BldgType',
#  'HouseStyle',
#  'RoofStyle',
#  'RoofMatl',
#  'Exterior1st',
#  'Exterior2nd',
#  'ExterQual',
#  'ExterCond',
#  'Foundation',
#  'Heating',
#  'HeatingQC',
#  'CentralAir',
#  'KitchenQual',
#  'Functional',
#  'GarageYrBlt',
#  'PavedDrive',
#  'SaleType',
#  'SaleCondition']

# %%
df[categorical_data].isna().sum()
# Out:
# MSZoning         0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        0
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# ExterQual        0
# ExterCond        0
# Foundation       0
# Heating          0
# HeatingQC        0
# CentralAir       0
# KitchenQual      0
# Functional       0
# GarageYrBlt      0
# PavedDrive       0
# SaleType         0
# SaleCondition    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()

for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = label_encoder.fit_transform(df[column].astype(str))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Columns: 107 entries, Id to G_encoded
# dtypes: float64(2), int32(28), int64(77)
# memory usage: 1.0 MB

# %%
df
# Out:
#         Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley_1  \
# 0        1          60         3         65.0     8450       1        1
# 1        2          20         3         80.0     9600       1        1
# 2        3          60         3         68.0    11250       1        1
# 3        4          70         3         60.0     9550       1        1
# 4        5          60         3         84.0    14260       1        1
# ...    ...         ...       ...          ...      ...     ...      ...
# 1455  1456          60         3         62.0     7917       1        1
# 1456  1457          20         3         85.0    13175       1        1
# 1457  1458          70         3         66.0     9042       1        1
# 1458  1459          20         3         68.0     9717       1        1
# 1459  1460          20         3         75.0     9937       1        1
#
#       Alley_2  Alley_3  LotShape  ...  MiscVal  MoSold  YrSold  SaleType  \
# ...

# %%
df.drop(columns=["Id","YrSold","GarageYrBlt"],axis=1,inplace=True)

# %%
df
# Out:
#       MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley_1  Alley_2  \
# 0             60         3         65.0     8450       1        1        0
# 1             20         3         80.0     9600       1        1        0
# 2             60         3         68.0    11250       1        1        0
# 3             70         3         60.0     9550       1        1        0
# 4             60         3         84.0    14260       1        1        0
# ...          ...       ...          ...      ...     ...      ...      ...
# 1455          60         3         62.0     7917       1        1        0
# 1456          20         3         85.0    13175       1        1        0
# 1457          70         3         66.0     9042       1        1        0
# 1458          20         3         68.0     9717       1        1        0
# 1459          20         3         75.0     9937       1        1        0
#
# ...

# %%
x=df.drop("SalePrice",axis=1)

y=df["SalePrice"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2, random_state=100)

# %%
from sklearn.linear_model import LinearRegression

# %%
l_r = LinearRegression()

# %%
l_r.fit(x_train, y_train)
y_pred = l_r.predict(x_test)

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
print("MAE = ", mean_absolute_error(y_test, y_pred))
print("MSE = ", mean_squared_error(y_test, y_pred))
print("RMSE = ", np.sqrt(mean_squared_error(y_test, y_pred)))
print("R Squared = ", r2_score(y_test, y_pred))
# Out:
# MAE =  21044.666296304866
# MSE =  933869719.9807279
# RMSE =  30559.282059314286
# R Squared =  0.8547430981701702
